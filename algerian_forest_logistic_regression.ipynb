# %% [markdown]
# ### Algerian dataset without data imbalance techniques

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ManjunathSirur\Desktop\Desktop\jupyter notebooks\inueron assignments\algerian_forest_logistic_regression\Algerian_forest_fires_dataset_UPDATE.csv", skiprows=1)
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes
# 0     3.4  0.5   not fire
# ...

# %%
for i in df.columns:
    df.rename(columns={i:i.strip()}, inplace=True)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
df['Classes'] = df['Classes'].str.strip()
df['Classes'].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      244 non-null    object
# dtypes: float64(6), int64(6), object(2)
# memory usage: 26.8+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(6), int64(6), object(2)
# memory usage: 28.5+ KB

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
col_list = ['Temperature','RH','Ws','Rain','FFMC','DMC','DC','ISI','BUI','FWI']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(df['Temperature'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['RH'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Ws'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Rain'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['FFMC'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['DMC'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['DC'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['ISI'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['BUI'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['FWI'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for x in df.columns:
    print(f'''
    {x} : {df[x].value_counts()}
    ''')
# Out:
#     day : 1     8
# 17    8
# 30    8
# 29    8
# 28    8
# 27    8
# 26    8
# 25    8
# 24    8
# 23    8
# 22    8
# 21    8
# 20    8
# 19    8
# 18    8
# 16    8
# 2     8
# 15    8
# 13    8
# 12    8
# 11    8
# 10    8
# 9     8
# 8     8
# 7     8
# 6     8
# 5     8
# 4     8
# 3     8
# 14    7
# 31    4
# Name: day, dtype: int64
#
#
#     month : 8    62
# 7    61
# 6    60
# 9    60
# Name: month, dtype: int64
#
#
#     year : 2012    243
# Name: year, dtype: int64
#
#
#     Temperature : 35    29
# 31    25
# 34    24
# 33    23
# 30    22
# 32    21
# 36    21
# 29    18
# 28    15
# 27     8
# 37     8
# 25     6
# 39     6
# 26     5
# 24     3
# 38     3
# 40     3
# 22     2
# 42     1
# Name: Temperature, dtype: int64
#
#
#     RH : 64    10
# 55    10
# 58     8
# 54     8
# 78     8
#       ..
# 21     1
# 90     1
# 24     1
# 38     1
# 26     1
# Name: RH, Length: 62, dtype: int64
#
#
#     Ws : 14    43
# 15    40
# 13    30
# 17    28
# 16    27
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
sns.boxplot(data=df['Temperature']);

# %%
sns.boxplot(data=df['RH']);

# %%
sns.boxplot(data=df['Ws']);

# %%
sns.boxplot(data=df['Rain']);

# %%
df['Rain'] = df['Rain'].apply(lambda x: 2.4 if x>=2.4 else x )

# %%
sns.boxplot(data=df['Rain']);

# %%
sns.boxplot(data=df['FFMC']);

# %%
df['FFMC'] = df['FFMC'].apply(lambda x: 55 if x<=55 else x )
sns.boxplot(data=df['FFMC']);

# %%
sns.boxplot(data=df['DMC']);

# %%
df['DMC'] = df['DMC'].apply(lambda x: 45 if x>=45 else x )
sns.boxplot(data=df['DMC']);

# %%
sns.boxplot(data=df['DC']);

# %%
df['DC'] = df['DC'].astype('float')

# %%
df['DC'] = df['DC'].apply(lambda x: 115 if x>=115 else x )
sns.boxplot(data=df['DC']);

# %%
sns.boxplot(data=df['ISI']);

# %%
sns.boxplot(data=df['BUI']);

# %%
df['BUI'] = df['BUI'].apply(lambda x: 55 if x>=55 else x )
sns.boxplot(data=df['BUI']);

# %%
sns.boxplot(data=df['FWI']);

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22   2.4  55.0   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.4  55.0   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   2.4  55.0   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  55.0   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
sns.distplot(df['Temperature'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['RH'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Ws'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Rain'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['FFMC'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['DMC'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['DC'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['ISI'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['BUI'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['FWI'], kde=True);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
sns.stripplot(df['Classes'],df['Temperature']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['RH']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['Ws']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['Rain']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['FFMC']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['DMC']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['DC']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['ISI']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['BUI']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df['Classes'],df['FWI']);
# Out:
# C:\Users\ManjunathSirur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = df.iloc[:,:-1]

# %%
y = df['Classes']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[-1.67279579, -1.35016751,  0.        , ..., -0.83035573,
#         -0.96708241, -0.88015863],
#        [-1.55947285, -1.35016751,  0.        , ..., -0.90272026,
#         -0.93009069, -0.8936262 ],
#        [-1.44614991, -1.35016751,  0.        , ..., -1.07157084,
#         -1.01887082, -0.93402893],
#        ...,
#        [ 1.38692352,  1.34646842,  0.        , ..., -1.04744933,
#         -0.96708241, -0.92056135],
#        [ 1.50024646,  1.34646842,  0.        , ..., -0.73386968,
#         -0.84131055, -0.85322348],
#        [ 1.6135694 ,  1.34646842,  0.        , ..., -0.85447724,
#         -0.86350558, -0.88015863]])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x_scaled,y, test_size=0.3, random_state=123)

# %%
x_train
# Out:
# array([[ 1.16027765, -1.35016751,  0.        , ...,  0.54457042,
#         -0.00529758,  0.33192306],
#        [ 0.02704827,  1.34646842,  0.        , ...,  2.28131923,
#          0.43860311,  1.65174533],
#        [-1.1061811 , -0.45128887,  0.        , ..., -0.10671039,
#          0.01689745, -0.09903932],
#        ...,
#        [-1.1061811 ,  0.44758978,  0.        , ...,  0.11038321,
#         -0.16806117, -0.03170145],
#        [-1.21950404, -1.35016751,  0.        , ..., -0.70974817,
#         -0.73773372, -0.82628833],
#        [ 0.25369415,  1.34646842,  0.        , ...,  0.49632739,
#         -0.38261317,  0.08950672]])

# %%
x_test
# Out:
# array([[-6.52889351e-01,  1.34646842e+00,  0.00000000e+00,
#         -8.70654693e-01,  8.08160320e-01, -1.76015152e-01,
#          8.64721872e-01, -1.61390320e+00, -8.47827920e-01,
#         -1.00044065e+00, -9.50963287e-01, -8.78302272e-01,
#         -9.07093779e-01],
#        [ 4.80340023e-01, -1.35016751e+00,  0.00000000e+00,
#         -5.94454836e-01,  1.21363098e+00,  1.80415531e-01,
#         -5.45855682e-02, -1.58887372e+00, -9.61758854e-01,
#         -4.81995092e-01, -9.26841776e-01, -8.41310548e-01,
#         -8.93626205e-01],
#        [ 1.50024646e+00, -1.35016751e+00,  0.00000000e+00,
#          1.33894416e+00, -1.75982055e+00, -8.88876518e-01,
#          2.08073701e-01,  6.13719943e-01,  3.09009257e-01,
#         -2.18657664e-01,  1.38971670e-02,  9.82792476e-02,
#          2.21688466e-02],
#        [-7.66212289e-01,  4.47589777e-01,  0.00000000e+00,
#          1.89134388e+00, -1.28677144e+00, -1.24530720e+00,
#         -5.79904106e-01,  1.07259362e+00,  1.86314405e-01,
# ...

# %%
y_train
# Out:
# 147        fire
# 229        fire
# 157        fire
# 41     not fire
# 213        fire
#          ...
# 98     not fire
# 221        fire
# 66         fire
# 126    not fire
# 109        fire
# Name: Classes, Length: 170, dtype: object

# %%
y_test
# Out:
# 223    not fire
# 19     not fire
# 150        fire
# 191        fire
# 31     not fire
#          ...
# 185        fire
# 212        fire
# 50         fire
# 188    not fire
# 237    not fire
# Name: Classes, Length: 73, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

LG = LogisticRegression()
LG.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = LG.predict(x_test)
y_pred
# Out:
# array(['not fire', 'not fire', 'fire', 'fire', 'not fire', 'fire', 'fire',
#        'fire', 'not fire', 'fire', 'not fire', 'fire', 'fire', 'fire',
#        'fire', 'fire', 'not fire', 'fire', 'fire', 'not fire', 'not fire',
#        'fire', 'not fire', 'fire', 'fire', 'not fire', 'fire', 'not fire',
#        'fire', 'not fire', 'not fire', 'fire', 'fire', 'fire', 'not fire',
#        'fire', 'fire', 'not fire', 'not fire', 'fire', 'fire', 'not fire',
#        'not fire', 'not fire', 'fire', 'fire', 'not fire', 'fire', 'fire',
#        'not fire', 'fire', 'fire', 'fire', 'not fire', 'fire', 'fire',
#        'not fire', 'fire', 'fire', 'not fire', 'fire', 'fire', 'not fire',
#        'fire', 'not fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire',
#        'not fire', 'not fire'], dtype=object)

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9041095890410958

# %%
precision_score(y_test, y_pred, pos_label="not fire")
# Out:
# 0.9285714285714286

# %%
recall_score(y_test, y_pred, pos_label="fire")
# Out:
# 0.9523809523809523
